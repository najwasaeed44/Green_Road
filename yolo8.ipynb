# %%
# !nvidia-smi
# Out:
# Wed Jan 11 11:54:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Ultralytics YOLOv8.0.3 🚀 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
# Out:
# ...
#   0%|          | 0.00/6.24M [00:00<?, ?B/s]

# %%
# !unzip /content/drive/MyDrive/road_damage.zip -d /content/data

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=/content/yolov8n.pt data=/content/dataset.yaml epochs=50 imgsz=640
# Out:
# /content
# ...

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/dataset.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.3 🚀 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Fusing layers...
# Model summary: 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/data/val/labels.cache... 1937 images, 223 backgrounds, 0 corrupt: 100% 1937/1937 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 122/122 [00:22<00:00,  5.39it/s]
#                    all       1937       3510      0.614       0.59       0.62      0.332
#                    D00       1937       1315       0.58      0.605      0.603      0.327
#                    D10       1937        758      0.569      0.478      0.532       0.24
#                   D20'       1937        895      0.662      0.582      0.662       0.35
#                    D44       1937        542      0.645      0.694      0.684      0.409
# Speed: 0.5ms pre-process, 3.7ms inference, 0.0ms loss, 1.6ms post-process per image
